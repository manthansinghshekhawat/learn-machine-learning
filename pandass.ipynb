# %%
1+2

# %%
import pandas as pd
import numpy as np

# %%
##Creating a series

# %%
labels = ['a','b','c']
my_arr= np.array([1,2,3])
my_dict={1:10,2:33,3:34}

# %%
pd.Series(my_arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(my_arr, labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# 1    10
# 2    33
# 3    34
# dtype: int64
