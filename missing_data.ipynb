# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

# %%
miles = pd.DataFrame({'farthest_run_mi' :[50,62,np.nan,100,26,13,31,50]})

# %%
miles
# Out:
#    farthest_run_mi
# 0             50.0
# 1             62.0
# 2              NaN
# 3            100.0
# 4             26.0
# 5             13.0
# 6             31.0
# 7             50.0

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean = SimpleImputer(strategy='mean')
SimpleImputer(strategy='mean').fit_transform(miles)
# Out:
# array([[ 50.        ],
#        [ 62.        ],
#        [ 47.42857143],
#        [100.        ],
#        [ 26.        ],
#        [ 13.        ],
#        [ 31.        ],
#        [ 50.        ]])

# %%
imp_median = SimpleImputer(strategy='median')
SimpleImputer(strategy='median').fit_transform(miles)
# Out:
# array([[ 50.],
#        [ 62.],
#        [ 50.],
#        [100.],
#        [ 26.],
#        [ 13.],
#        [ 31.],
#        [ 50.]])
